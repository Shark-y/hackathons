# %% [markdown]
# # Entanglemments - Bell States
#
# In this exercise we will create cuircuits for the 4 Bell states (2 qubit entanglements) and GHZ (3 qubit entanglement) with noiseless and noise models.
#
# See https://en.wikipedia.org/wiki/Bell_state
#
# ![](ss1.png "Bell States")
#
# ## Load libs

# %%
from qiskit import *
from qiskit.visualization import *

# %% [markdown]
# ## Create a 2 qubit Quantum Circuit

# %%
# Add code here.. Tip: QuantumCircuit(2) - https://docs.quantum.ibm.com/api/qiskit/qiskit.circuit.QuantumCircuit
#qc1 = ...

# %% [markdown]
# Create the 1st Bell (entagled state() $\phi_+ = (|00> + |11>)\sqrt{2}$

# %%
# Add your code here...

# %% [markdown]
# Draw the circuit

# %%
# Add code to draw the circuit. Tip: invoke draw()
# Out:
# C:\Python\Python312\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# # Execution in Noiseless simulator
# Create a simulator backend abd run your circuit

# %%
# Add code to get a simulator object. See Aer (get backend)

# Add code to execute the qc in the sim and get the counts
# Tip: use the execute method -> result -> get counts

# %% [markdown]
# ## Plot result probabilities
#
# Verify they match  $\phi_+ = (|00> + |11>)\sqrt{2}$

# %%
# Plot the histogram here ... See https://docs.quantum.ibm.com/api/qiskit/visualization

# %% [markdown]
# ## Creater Another quantum Circuit (qc2) for the 2nd Bell State
#
# $\huge\phi_- = (|00> - |11>)/\sqrt{2}$

# %%
# Add code for the 2nd bell state 
#qc2 = ...

# %% [markdown]
# ## Get the state in a DensityMatrix or StateVector

# %%
from qiskit.quantum_info import DensityMatrix,Statevector

# Add code to get the DensityMatrix see https://docs.quantum.ibm.com/api/qiskit/qiskit.quantum_info.DensityMatrix
#state =

# %% [markdown]
# Plot using a state city to see the phase (negative sign).
#
# Verify the correct results

# %%
# Plot a state city here... See https://docs.quantum.ibm.com/api/qiskit/qiskit.visualization.plot_state_city

# %% [markdown]
# ## Creater Another quantum Circuit (qc3) for the 3rd Bell State
#
# $\huge\theta_+ = (|01> + |10>)/\sqrt{2}$

# %%
# Add code here...

# %% [markdown]
# ## Run in the Simulator
#
# Plot the result probabilities. Verify they match $\phi_- = (|01> + |10>)/\sqrt{2}$

# %%
# Add code here
#counts3 = execute (...).result()....etc

#plot_....

# %% [markdown]
# ## Creater Another quantum Circuit (qc4) for the 4rd Bell State
#
# $\huge\theta_- = (|10> - |01>)/\sqrt{2}$

# %%
# Add code here...
# Out:
# C:\Python\Python312\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# ## Get the state vector and Plot a Qsphere to see the phase
# https://docs.quantum.ibm.com/api/qiskit/qiskit.visualization.plot_state_qsphere
#
# Verify $\huge\theta_- = (|10> - |01>)/\sqrt{2}$

# %%
# Add code here...
# Get the density matrix state
#state4 = ...

# Plot qsphere. See https://docs.quantum.ibm.com/api/qiskit/qiskit.visualization.plot_state_qsphere
#plot_state_....

# %% [markdown]
# ## Create a Circuit for a GHZ State
#
# It defines a 3 qubit entanglement. See https://en.wikipedia.org/wiki/Greenberger%E2%80%93Horne%E2%80%93Zeilinger_state
#
# ![](ss2.png "Bell States")

# %%
# Add code Here...
# Out:
# C:\Python\Python312\Lib\site-packages\qiskit\visualization\circuit\matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
# Run in the simulator and Plot/verify results. Add code here
#counts = execute ....

#plot_histogram ...

# %% [markdown]
# ## Optinally - Add a Noise Model
# https://qiskit.github.io/qiskit-aer/tutorials/3_building_noise_models.html

# %%
# Optionally run with a Noise Mdels
# Import from Qiskit Aer noise module
from qiskit_aer.noise import (NoiseModel, QuantumError, ReadoutError,
    pauli_error, depolarizing_error, thermal_relaxation_error)

def get_noise_model(p_reset, p_meas, p_gate1) :
    # QuantumError objects
    error_reset = pauli_error([('X', p_reset), ('I', 1 - p_reset)])
    error_meas = pauli_error([('X',p_meas), ('I', 1 - p_meas)])
    error_gate1 = pauli_error([('X',p_gate1), ('I', 1 - p_gate1)])
    error_gate2 = error_gate1.tensor(error_gate1)

    # Add errors to noise model
    noise_bit_flip = NoiseModel()
    noise_bit_flip.add_all_qubit_quantum_error(error_reset, "reset")
    noise_bit_flip.add_all_qubit_quantum_error(error_meas, "measure")
    noise_bit_flip.add_all_qubit_quantum_error(error_gate1, ["u1", "u2", "u3"])
    noise_bit_flip.add_all_qubit_quantum_error(error_gate2, ["cx"])
    return noise_bit_flip
    
noise_model = get_noise_model(0.1, 0.1, 0.1)

# %% [markdown]
# ## Run with noise
#
# Verify the noise in the probability counts.

# %%
from qiskit_aer import AerSimulator

# Create noisy simulator backend. See https://qiskit.github.io/qiskit-aer/stubs/qiskit_aer.AerSimulator.html
# See https://qiskit.github.io/qiskit-aer/tutorials/3_building_noise_models.html
#sim_noise = AerS...

# %%
# Run in the simulator and Plot/verify results. Add code...

# Transpile circuit for noisy basis gates
#qc_noise = transp...

# Run with noise
#counts = execute ...

# Display noisy prob results
#plot_histogram...
